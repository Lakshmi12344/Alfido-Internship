# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshmi12344/Alfido-Internship/blob/main/Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def celsius_to_fahrenheit(c):
    return (c * 9/5) + 32

def celsius_to_kelvin(c):
    return c + 273.15

def fahrenheit_to_celsius(f):
    return (f - 32) * 5/9

def fahrenheit_to_kelvin(f):
    return (f - 32) * 5/9 + 273.15

def kelvin_to_celsius(k):
    return k - 273.15

def kelvin_to_fahrenheit(k):
    return (k - 273.15) * 9/5 + 32

while True:
    print("\nTemperature Converter")
    print("Choose conversion:")
    print("1. Celsius to Fahrenheit")
    print("2. Celsius to Kelvin")
    print("3. Fahrenheit to Celsius")
    print("4. Fahrenheit to Kelvin")
    print("5. Kelvin to Celsius")
    print("6. Kelvin to Fahrenheit")

    choice = int(input("Enter your choice (1-6): "))
    value = float(input("Enter the temperature value: "))

    if choice == 1:
        print("Fahrenheit:", celsius_to_fahrenheit(value))
    elif choice == 2:
        print("Kelvin:", celsius_to_kelvin(value))
    elif choice == 3:
        print("Celsius:", fahrenheit_to_celsius(value))
    elif choice == 4:
        print("Kelvin:", fahrenheit_to_kelvin(value))
    elif choice == 5:
        print("Celsius:", kelvin_to_celsius(value))
    elif choice == 6:
        print("Fahrenheit:", kelvin_to_fahrenheit(value))
    else:
        print("Invalid choice.")

    again = input("\nDo you want to convert another temperature? (yes/no): ").strip().lower()
    if again != "yes":
        print("Thank you for using the temperature converter!")
        break
# Out:
# Temperature Converter
# Choose conversion:
# 1. Celsius to Fahrenheit
# 2. Celsius to Kelvin
# 3. Fahrenheit to Celsius
# 4. Fahrenheit to Kelvin
# 5. Kelvin to Celsius
# 6. Kelvin to Fahrenheit
# Enter your choice (1-6): 1
# Enter the temperature value: 37
# Fahrenheit: 98.6
#
# Do you want to convert another temperature? (yes/no): yes
#
# Temperature Converter
# Choose conversion:
# 1. Celsius to Fahrenheit
# 2. Celsius to Kelvin
# 3. Fahrenheit to Celsius
# 4. Fahrenheit to Kelvin
# 5. Kelvin to Celsius
# 6. Kelvin to Fahrenheit
# Enter your choice (1-6): 2
# Enter the temperature value: 56
# Kelvin: 329.15
#
# Do you want to convert another temperature? (yes/no): yes
#
# Temperature Converter
# Choose conversion:
# 1. Celsius to Fahrenheit
# 2. Celsius to Kelvin
# 3. Fahrenheit to Celsius
# 4. Fahrenheit to Kelvin
# 5. Kelvin to Celsius
# 6. Kelvin to Fahrenheit
# Enter your choice (1-6): 3
# Enter the temperature value: 67
# Celsius: 19.444444444444443
#
# ...
